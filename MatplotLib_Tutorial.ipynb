# %% [markdown]
# <a href="https://colab.research.google.com/github/Patelriki28/RP-Websoft/blob/master/MatplotLib_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib
#
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %% [markdown]
# Import the `matplotlib.pyplot` module under the name `plt`

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Basic Example
#
# Lets quickly create a basic graph by generating a random sequence data to learn plotting

# %%
x = np.linspace(0, 10, 40)
y = x ** 2
print(x)
print(y)
# Out:
# [ 0.          0.25641026  0.51282051  0.76923077  1.02564103  1.28205128
#   1.53846154  1.79487179  2.05128205  2.30769231  2.56410256  2.82051282
#   3.07692308  3.33333333  3.58974359  3.84615385  4.1025641   4.35897436
#   4.61538462  4.87179487  5.12820513  5.38461538  5.64102564  5.8974359
#   6.15384615  6.41025641  6.66666667  6.92307692  7.17948718  7.43589744
#   7.69230769  7.94871795  8.20512821  8.46153846  8.71794872  8.97435897
#   9.23076923  9.48717949  9.74358974 10.        ]
# [0.00000000e+00 6.57462196e-02 2.62984878e-01 5.91715976e-01
#  1.05193951e+00 1.64365549e+00 2.36686391e+00 3.22156476e+00
#  4.20775805e+00 5.32544379e+00 6.57462196e+00 7.95529257e+00
#  9.46745562e+00 1.11111111e+01 1.28862590e+01 1.47928994e+01
#  1.68310322e+01 1.90006575e+01 2.13017751e+01 2.37343853e+01
#  2.62984878e+01 2.89940828e+01 3.18211703e+01 3.47797502e+01
#  3.78698225e+01 4.10913872e+01 4.44444444e+01 4.79289941e+01
# ...

# %%
plt.plot(x,y)

# %% [markdown]
# #Basic Matplotlib commands

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('Number range')
plt.ylabel('Squared Output')
plt.title('String Title Here')
plt.show()

# %%
plt.plot(x, y, 'b') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %% [markdown]
# #Figures and Axes
#
# fig.add_axes([0, 0, 1, 1])
#
# *   At 1st position 0 represent extreme left of the figure and 1 represent extreme right of the figure.
# *   At 2nd position 0 represents bottom of the figure and 1 represents top of the figure.
# *   At 3rd position width of the figure.
# *   At 4th position height of the figure.

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0.6, 1, 0.4])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])
plt.show()

# %%
  # Figure inside another figure
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.5, 0.5, 0.4, 0.4])
plt.show()

# %%
#Multiple graphs on same layout
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 0.2])
ax2 = fig.add_axes([0.7, 0, 0.3, 0.9])
ax3 = fig.add_axes([0, 0.4, 0.6, 0.5])
ax4 = fig.add_axes([0, 0, 0.25, 0.3])
ax5 = fig.add_axes([0.35, 0, 0.25, 0.3])
plt.show()

# %%
#Adding data to graph
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 0.2])
ax1.plot(x, np.sin(x))
ax2 = fig.add_axes([0.7, 0, 0.3, 0.9])
ax2.plot(x, np.cos(x))
ax3 = fig.add_axes([0, 0.4, 0.6, 0.5])
ax3.plot(x, np.tan(x))
ax4 = fig.add_axes([0, 0, 0.25, 0.3])
ax4.plot(x, x**3)
ax5 = fig.add_axes([0.35, 0, 0.25, 0.3])
ax5.plot(x, x**4)
plt.show()

# %% [markdown]
# # Formatting the Axes and plots

# %%
#Customizing Axes font and color
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 1])
ax1.plot(x, np.sin(x),'g')
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=20, color='b')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
#Formating plot line color and shape
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 1])
ax1.plot(x, np.sin(x),'g_')
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=20, color='b')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
#Plotting multiple data points
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 1])
ax1.plot(x, np.sin(x),'g.')
ax1.plot(x, np.cos(x))
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=20, color='b')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
#Adding Legend
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 1])
ax1.plot(x, np.sin(x),'g.', label = 'sin(x)')
ax1.plot(x, np.cos(x), label = 'cos(x)')
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=20, color='b')
ax1.legend(loc = 3)

#ax.legend(loc=2) # upper left corner
#ax.legend(loc=3) # lower left corner
#ax.legend(loc=4) # lower right corner
#ax.legend(loc=0) # let matplotlib decide the optimal location

# %%
#Customizing range
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 1])
ax1.plot(x, np.sin(x),'g.', label = 'sin(x)')
ax1.plot(x, np.cos(x), label = 'cos(x)')
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=20, color='b')
ax1.set_xlim([0,10])
ax1.set_ylim([-3,3])
ax1.legend(loc = 1)

# %%
#Adding text to plots
fig = plt.figure()
ax1 = fig.add_axes([0, 1, 1, 1])
ax1.plot(x, np.sin(x),'g.')
ax1.plot(x, np.cos(x))
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=20, color='b')
ax1.text(0.9,0, 'Perfect Plan B', fontsize = 15, color = 'red')
# Out:
# Text(0.9, 0, 'Perfect Plan B')

# %% [markdown]
# # Plot *Types*

# %% [markdown]
# ## Line Plot

# %%
# Line Plot
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x), 'b-');

# %% [markdown]
# ## Bar Chart
#
# Bar charts display rectangular bars either in vertical or horizontal form. Their length is proportional to the values they represent. They are used to compare two or more values.

# %%
# Bar Chart

x = [5. , 25. , 50. , 20.]
plt.bar(range(len(x)), x)
plt.show()

# %% [markdown]
# ## Horizontal Bar Chart
#
# Similar to bar chart but the bars are horizontally aligned.

# %%
# Horizontal Bar Chart

x = [5. , 25. , 50. , 20.]
plt.barh(range(len(x)), x)
plt.show()

# %% [markdown]
# ## Stacked Bar Chart
#
# Stacked bar chart is used when the each bar has multiple catergories within them.

# %%
x = [15., 30., 45., 22.]
y = [15., 25., 50., 20.]
z = range(4)

plt.bar(z, x, color = 'b')
plt.bar(z, y, color = 'r', bottom = x)

plt.show()

# %% [markdown]
# ## Pie Chart
#
# Pie charts are circular representations, divided into sectors. The sectors are also called wedges. The arc length of each sector is proportional to the quantity we are describing. It is an effective way to represent information when we are interested mainly in comparing the wedge against the whole pie, instead of wedges against each other.

# %%
plt.figure(figsize=(7,7))
x10 = [35, 25, 20, 20]
labels = ['Computer', 'Electronics', 'Mechanical', 'Chemical']
plt.pie(x10, labels=labels);
plt.show()

# %% [markdown]
# ## Box Plot
#
# Boxplot allows us to compare distributions of values by showing the median, quartiles, maximum and minimum of a set of values.

# %%
x = np.random.randn(100)
np.append(x,200)
np.append(x,1000)
plt.boxplot(x)
plt.show()

# %% [markdown]
# ## Area Chart
#
# An Area Chart is very similar to a Line Chart. The area between the x-axis and the line is filled in with color or shading. It represents the evolution of a numerical variable following another numerical variable.

# %%
# Area Chart
days = [1,2,3,4,5]

sleeping = [7,8,6,11,7]
eating =   [2,3,4,3,2]
working =  [7,8,7,2,2]
playing =  [8,5,7,8,13]
plt.stackplot(days, sleeping,eating,working,playing, colors=['m','c','r','k'])

plt.xlabel('x')
plt.ylabel('y')
plt.title('Area Plots')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
x = [1,2,3,4,5,6,7,8]
y = [5,2,4,2,1,4,5,2]

plt.scatter(x,y, marker="o")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter Plot')
plt.show()
